# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#  __Sanika Atul Bhanage__

# %% [markdown]
# *I am interested in data science because it follows with lot of new opportunities. It is good practise to understand about the data, their requirements in industries. I also interested because it is something new to learn and very useful.*

# %% [markdown]
# ### python code for find string is palindrome or not.

# %%
string = "JupyterNoteBookkooBetoNretypuJ"

if string == string[::-1]:
    print("String is palindrome")
else:
    print("String is not palindrome")
# Out:
# String is palindrome

# %% [markdown]
# > IBM cloud Watson studio
# - This is circular bullet
# 1. This is number bullet
# 2. <a id="Section ID">HyperLink</a>
# 3. <img src="https://images.pexels.com/photos/736230/pexels-photo-736230.jpeg" alt="Alt text" title="Title text" width="200" height="200"/>
# - <a href="http://url" target="_blank" rel="noopener noreferrer">External link text</a>
